# %% [markdown]
# # Executing PG-RAD example

# %%
! pgrad --example --save
# Out:
# (250.0, 30.0, 0.0)
# 2026-03-31 13:33:05,003 - INFO: Landscape built successfully: Example landscape
# 2026-03-31 13:33:05,012 - INFO: Simulation output saved to example_landscape_result_20260331_1333!

# %%
from pandas import read_csv

# %%
df = read_csv("example_landscape_result_20260331_1333/1_src_15_cps_bkg_100MBq_30m_250_30.csv")

# %%
df
# Out:
#            East       North      ROI_P  ROI_BR    Dist
# 0      8.330000    0.000000   0.000000  14.745    0.00
# 1     16.660000    0.000000  15.913284  14.745    8.33
# 2     24.990000    0.000000  13.110951  14.745   16.66
# 3     33.320000    0.000000  12.960828  14.745   24.99
# 4     41.650000    0.000000  12.410372  14.745   33.32
# ..          ...         ...        ...     ...     ...
# 116  935.005103  160.664412  13.251282  14.745  966.28
# 117  941.195500  166.238270  13.045235  14.745  974.61
# 118  947.312406  171.892680  15.192090  14.745  982.94
# 119  953.354775  177.626674  12.936051  14.745  991.27
# 120  959.321570  183.439268  13.633114  14.745  999.60
#
# [121 rows x 5 columns]
