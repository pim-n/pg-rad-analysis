# %% [markdown]
# # Experimental background plots

# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## 1. Field efficiency as a function of energy

# %%
from pg_rad.utils.interpolators import get_field_efficiency

# %%
NAME = 'LU_NaI_3inch'

# %%
E = np.linspace(10, 2000, 100)
eff = get_field_efficiency(NAME, E)
plt.plot(E, eff)
plt.grid()
plt.xlabel("E$_\\gamma$ (keV)")
plt.ylabel("Field efficiency $\\varepsilon$")
# Out:
# Text(0, 0.5, 'Field efficiency $\\varepsilon$')

# %% [markdown]
# ## 2. Angular effiency
